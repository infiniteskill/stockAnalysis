# %%
import pandas as pd
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)

# %%
df=pd.read_csv('A_EQUITY_ACTIVE.CSV')

# %%
df.sort_values
# Out:
#      Unnamed: 0  Security Code Security Id  \
# 0           291         532532  JPASSOCIAT
# 1           350         532939      RPOWER
# 2           305         532667      SUZLON
# 3           329         532822        IDEA
# 4           194         521064     TRIDENT
# 5            24         500106        IFCI
# 6            48         500219  JISLJALEQS
# 7            27         500111  RELCAPITAL
# 8           209         523756    SREINFRA
# 9           266         532388         IOB
# 10          165         511072        DHFL
# 11          252         532218   SOUTHBANK
# 12          333         532839      DISHTV
# 13          284         532505     UCOBANK
# 14          276         532480        ALBK
# 15          268         532418  ANDHRABANK
# 16           44         500183        HFCL
# 17          341         532885   CENTRALBK
# 18          366         533162     HATHWAY
# 19          386         534690  LAKSHVILAS
# 20          249         532209     J&KBANK
# ...
